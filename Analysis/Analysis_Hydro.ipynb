# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hydro_era5 = pd.read_parquet('/Users/darcor/Data/EDP Thesis/Output/Hydro_era5.parquet', engine="fastparquet")

# %%
wind_rcp_26 = pd.read_parquet('/Users/darcor/Data/EDP Thesis/Output/Wind_rcp_2_6.parquet', engine="fastparquet")

# %%
hydro_era5.describe()
# Out:
#        Total Capacity (MW)  Average Annual Productivity (GWh)  \
# count         1.071258e+06                      939700.000000
# mean          1.105281e+02                         239.648000
# min           1.000000e-01                           0.100000
# 25%           1.320000e+01                          40.000000
# 50%           5.800000e+01                         120.000000
# 75%           1.800000e+02                         327.000000
# max           7.360000e+02                        1441.000000
# std           1.391517e+02                         301.706568
#
#        Total Storage (hm3)      latitude     longitude  Capacity Factor  \
# count        620202.000000  1.071258e+06  1.071258e+06    958494.000000
# mean            119.198788  4.086830e+01 -7.812416e+00         0.327096
# min               0.000000  3.811044e+01 -8.761326e+00         0.000000
# 25%              12.000000  4.038498e+01 -8.196959e+00         0.177169
# ...

# %%
hydro_era5["tp"].mean()
# Out:
# 0.00014696307

# %%
hydro_era5["t2m"].plot(title="Temperature in Kalvin", figsize=(12, 6))
# Out:
# <Axes: title={'center': 'Temperature in Kalvin'}>

# %%
hydro_era5_predictions = pd.read_parquet('/Users/darcor/Data/EDP Thesis/Output/Predictions/Hydro_era5_w_predictions_15min.parquet', engine="fastparquet")
